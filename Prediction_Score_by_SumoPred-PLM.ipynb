# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
position = []
with open("Position_list_of_P10275.txt") as subash:
    for line in subash:
        x = line.strip("\n")
        position.append(int(x))
        
confidence = [0.3760439 , 0.48990715, 0.7794659 , 0.5594331 , 0.47103968,
       0.67510843, 0.9032195 , 0.5495005 , 0.7472038 , 0.7590583 ,
       0.68527544, 0.99477226, 0.9880437 , 0.21585205, 0.09761685,
       0.15734841, 0.19552708, 0.16889407, 0.26365227, 0.07959151,
       0.859822  , 0.12329257, 0.34888273, 0.70627034, 0.88646185,
       0.7114902 , 0.25086835, 0.1638331 , 0.36442465, 0.03339903,
       0.44081077, 0.5557054 , 0.3636891 , 0.20896572, 0.12637268,
       0.51911455, 0.08986624, 0.6831882 , 0.7492816 , 0.8538785 ]
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
plt.bar(position, confidence, color ='blue',
        width = 2)

decision_boundray_points = np.array([0.5 for i in range(920)])
plt.plot(decision_boundray_points, linestyle = 'dotted')

 
plt.xlabel("""lysine (K) residue position at P10275 protein""")
plt.ylabel("pLMSumoPred prediction score")
# plt.title("Students enrolled in different courses")

plt.savefig('Prediction_Score_by_pLMSumoPred.png', dpi=350, bbox_inches='tight')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt
 
  
position = []
with open("Position_list_of_P10275.txt") as subash:
    for line in subash:
        x = line.strip("\n")
        position.append(int(x))
        
confidence = [0.3760439 , 0.48990715, 0.7794659 , 0.5594331 , 0.47103968,
       0.67510843, 0.9032195 , 0.5495005 , 0.7472038 , 0.7590583 ,
       0.68527544, 0.99477226, 0.9880437 , 0.21585205, 0.09761685,
       0.15734841, 0.19552708, 0.16889407, 0.26365227, 0.07959151,
       0.859822  , 0.12329257, 0.34888273, 0.70627034, 0.88646185,
       0.7114902 , 0.25086835, 0.1638331 , 0.36442465, 0.03339903,
       0.44081077, 0.5557054 , 0.3636891 , 0.20896572, 0.12637268,
       0.51911455, 0.08986624, 0.6831882 , 0.7492816 , 0.8538785 ]
  
fig = plt.figure(figsize = (10, 5))
 
# creating the bar plot
ret = plt.bar(position, confidence, color ='blue',
        width = 2)

decision_boundray_points = np.array([0.5 for i in range(920)])
plt.plot(decision_boundray_points, linestyle = 'dotted', color = 'red')
ret[position.index(387)].set_color("green")
ret[position.index(520)].set_color("green")
ret[position.index(638)].set_color("green")
ret[position.index(910)].set_color("green")
ret[position.index(912)].set_color("green")




 
plt.xlabel("Sequence position")
plt.ylabel("SumoPred-PLM prediction score")
# plt.title("Students enrolled in different courses")

plt.savefig('Prediction_Score_by_SumoPred-PLM.png', dpi=600, bbox_inches='tight')
plt.show()
