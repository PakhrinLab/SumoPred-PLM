# %%
import numpy as np 
import pandas as pd 
import os
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from numpy import sort
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import *
from sklearn.metrics import roc_curve, roc_auc_score, classification_report,auc
import tensorflow.keras
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from tensorflow.keras.layers import Dense, Bidirectional,Dense, LSTM, Activation, Dropout, Flatten, LeakyReLU
from sklearn.metrics import accuracy_score
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers
from imblearn.under_sampling import RandomUnderSampler
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.applications import mobilenet_v2, mobilenet, resnet50, densenet
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D, Flatten, \
    BatchNormalization, Activation, GlobalAveragePooling2D, DepthwiseConv2D, \
    Dropout, ReLU, Concatenate, Input, add, Conv1D, MaxPooling1D
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
import matplotlib.pyplot as plt
import math
from tensorflow.keras.callbacks import CSVLogger
from datetime import datetime
import os.path
from scipy.spatial import distance
import scipy.io as sio
from sklearn.model_selection import KFold
from sklearn.model_selection import StratifiedKFold
from sklearn.metrics import accuracy_score
import os
from sklearn.model_selection import KFold
import numpy as np
import random
from Bio import SeqIO
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, Lambda
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Conv1D, MaxPooling1D
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from tensorflow.keras.backend import expand_dims
import tensorflow as tf
import pandas as pd
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.utils import shuffle
from sklearn.model_selection import train_test_split
import tensorflow.keras
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, Lambda
from tensorflow.keras.layers import Conv2D, MaxPooling2D
from tensorflow.keras.callbacks import ModelCheckpoint
import matplotlib.pyplot as plt
from tensorflow.keras.regularizers import l1,l2
from tensorflow.keras import backend as K
from tensorflow.keras.backend import expand_dims
import pandas as pd 
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_selection import SelectFromModel
from sklearn.svm import SVC
from sklearn.metrics import confusion_matrix
from sklearn.metrics import matthews_corrcoef
from sklearn.utils import shuffle
from sklearn.preprocessing import MinMaxScaler
from numpy import sort
from sklearn.feature_selection import SelectFromModel
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import precision_score, recall_score
from sklearn.metrics import *
from sklearn.metrics import roc_curve, roc_auc_score, classification_report,auc
import tensorflow.keras
from sklearn.model_selection import KFold
from sklearn.preprocessing import MinMaxScaler
from sklearn.utils import shuffle
from tensorflow.keras.layers import Dense, Bidirectional,Dense, LSTM, Activation, Dropout, Flatten, LeakyReLU
from sklearn.metrics import accuracy_score
from tensorflow.keras.regularizers import l2
from tensorflow.keras import regularizers
from sklearn.model_selection import GridSearchCV
from tensorflow.keras.models import Sequential
from tensorflow.keras.wrappers.scikit_learn import KerasClassifier
from tensorflow.keras.models import Sequential 
from tensorflow.keras.layers import LSTM
from tensorflow.keras.models import Model
from tensorflow.keras.applications import mobilenet_v2, mobilenet, resnet50, densenet
from tensorflow.keras.layers import Dense, MaxPooling2D, Conv2D, Flatten, \
    BatchNormalization, Activation, GlobalAveragePooling2D, DepthwiseConv2D, \
    Dropout, ReLU, Concatenate, Input, add, Conv1D, MaxPooling1D
from tensorflow.keras.layers import LSTM, GRU, SimpleRNN
from tensorflow.keras.callbacks import ModelCheckpoint
from tensorflow.keras import backend as K
from sklearn.ensemble import RandomForestClassifier
from sklearn.datasets import make_classification
import matplotlib.pyplot as plt
import math
from tensorflow.keras.callbacks import CSVLogger
from datetime import datetime
import os.path
from scipy.spatial import distance
import scipy.io as sio
import os

# %%
os.chdir('/home/t326h379/dbPTM_SUMO_Protein')

# %%
df_training_positive = pd.read_csv('Training_Positive_SUMOylaiton_3271_or_less.txt',header=None)

df_training_negative = pd.read_csv('Training_Negative_SUMOylaiton_51603_or_less.txt',header=None)

df_independent_negative = pd.read_csv('Independent_Testing_Negative_SUMOylaiton_Sites_4627_or_less.txt',header=None)

df_indpendent_positive = pd.read_csv('Independent_Testing_Positive_SUMOylaiton_Sites_369_or_less.txt',header=None)

# %%
Header_name = ["Position","PID","K"]

col_of_feature = [i for i in range(1,1025)]

Header_name = Header_name + col_of_feature

df_training_positive.columns = Header_name

# %%
len(set(df_training_positive["PID"]))
# Out:
# 954

# %%
df_training_negative.columns = Header_name

# %%
len(set(df_training_negative["PID"]))
# Out:
# 975

# %%
df_independent_negative.columns = Header_name

# %%
len(set(df_independent_negative["PID"]))
# Out:
# 109

# %%
df_indpendent_positive.columns = Header_name

# %%
len(set(df_indpendent_positive["PID"]))
# Out:
# 108

# %%
a = random.sample(range(1, 1000000), 100)
for i in range(len(a)):
    
    seed = a[i]
    Header_name = ["Position","PID","K"]

    col_of_feature = [i for i in range(1,1025)]

    Header_name = Header_name + col_of_feature

    df_training_positive.columns = Header_name
    df_training_negative.columns = Header_name

    frames = [df_training_positive, df_training_negative]

    O_linked_training = pd.concat(frames,ignore_index = True)

    df_Train_array = O_linked_training.drop(["Position","PID","K"],axis=1)
    df_Train_array = np.array(df_Train_array)

    X_train_full = df_Train_array

    y_train_full = np.array([1]*3215+[0]*51603)

    from sklearn.metrics import roc_curve, roc_auc_score, classification_report, auc
    from imblearn.under_sampling import RandomUnderSampler

    rus = RandomUnderSampler(random_state = seed)
    X_train, y_train = rus.fit_resample(X_train_full,y_train_full)

    x_train_train, x_val_val, y_train_train, y_val_val = train_test_split(X_train, y_train, test_size=0.1)  
    

    y_train_train = tf.keras.utils.to_categorical(y_train_train,2)
    y_val_val = tf.keras.utils.to_categorical(y_val_val,2)

    model = Sequential()

    model.add(Input(shape=(1024,)))

    model.add(Dense(64,activation='relu',name="Dense_1"))
    model.add(Dropout(0.3))

    model.add(Dense(2,activation='softmax',name="Dense_2"))

        

    model.compile(optimizer=tf.keras.optimizers.Adam(),loss="binary_crossentropy",metrics=["accuracy"])

    checkpointer = tf.keras.callbacks.ModelCheckpoint(filepath="ROC_ROC_Premise_Assumption.h5", 
                                    monitor = 'val_accuracy',
                                    verbose=0, 
                                    save_weights_only=False,
                                    save_best_only=True)

    reduce_lr_acc = tf.keras.callbacks.ReduceLROnPlateau(monitor='val_accuracy', factor=0.001, patience=5, verbose=1, min_delta=1e-4, mode='max')

    early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_accuracy',patience=5,mode='max')

    history = model.fit(x_train_train, y_train_train,epochs=400,verbose=1,batch_size=256,
                            callbacks=[checkpointer,reduce_lr_acc, early_stopping],validation_data=(x_val_val, y_val_val))

    Header_name = ["Position","PID","K"]

    col_of_feature = [i for i in range(1,1025)]

    Header_name = Header_name + col_of_feature

    df_indpendent_positive.columns = Header_name
    df_independent_negative.columns = Header_name

    frames = [df_indpendent_positive, df_independent_negative]

    O_linked_test = pd.concat(frames,ignore_index = True)

    df_Test_array = O_linked_test.drop(["Position","PID","K"],axis=1)
    df_Test_array = np.array(df_Test_array)

    X_test_test_full = df_Test_array

    y_test_test_full = np.array([1]*368+[0]*4627)

    from sklearn.metrics import roc_curve, roc_auc_score, classification_report, auc
    from imblearn.under_sampling import RandomUnderSampler

    rus = RandomUnderSampler(random_state = seed)
    X_Independent, y_independent = rus.fit_resample(X_test_test_full,y_test_test_full)
    

    Y_pred = model.predict(X_Independent)
    Y_pred = (Y_pred > 0.5)
    y_pred = [np.argmax(y, axis=None, out=None) for y in Y_pred]
    y_pred = np.array(y_pred)

    confusion = confusion_matrix(y_independent,y_pred)

    print("Matthews Correlation : ",matthews_corrcoef(y_independent, y_pred))
    print("Confusion Matrix : \n",confusion_matrix(y_independent, y_pred))
    print("Accuracy on test set:   ",accuracy_score(y_independent, y_pred))

    cm = confusion_matrix(y_independent, y_pred)

    TP = cm[1][1]
    TN = cm[0][0]
    FP = cm[0][1]
    FN = cm[1][0]

    mcc = matthews_corrcoef(y_independent, y_pred)

    Sensitivity = TP/(TP+FN)

    Specificity = TN/(TN+FP)

    print("Sensitivity:   ",Sensitivity,"\t","Specificity:   ",Specificity)

    print(classification_report(y_independent, y_pred))

    fpr, tpr, _ = roc_curve(y_independent, y_pred)

    roc_auc_test = auc(fpr,tpr)



    print("Area Under Curve:   ",roc_auc_test)

    print("Precision:   ",TP/(TP+FP))
    model.save("dbPTM_ANN_program_first_revision"+str(i)+".h5")
    print()
    print("Seed   :    ",i)
    print()
    print("dbPTM_ANN_program_first_revision"+str(i)+".h5")
# Out:
# Epoch 1/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.5953 - accuracy: 0.6660 - val_loss: 0.5455 - val_accuracy: 0.7030
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5234 - accuracy: 0.7411 - val_loss: 0.5117 - val_accuracy: 0.7403
# Epoch 3/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4897 - accuracy: 0.7607 - val_loss: 0.5022 - val_accuracy: 0.7372
# Epoch 4/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4710 - accuracy: 0.7743 - val_loss: 0.4905 - val_accuracy: 0.7543
# Epoch 5/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4521 - accuracy: 0.7821 - val_loss: 0.4884 - val_accuracy: 0.7621
# Epoch 6/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4323 - accuracy: 0.8020 - val_loss: 0.4798 - val_accuracy: 0.7558
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4187 - accuracy: 0.8141 - val_loss: 0.4807 - val_accuracy: 0.7574
# Epoch 8/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4035 - accuracy: 0.8222 - val_loss: 0.4757 - val_accuracy: 0.7558
# Epoch 9/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3919 - accuracy: 0.8284 - val_loss: 0.4748 - val_accuracy: 0.7621
# Epoch 10/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3683 - accuracy: 0.8320
# Epoch 00010: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3779 - accuracy: 0.8409 - val_loss: 0.4782 - val_accuracy: 0.7589
# Matthews Correlation :  0.45924082600452576
# Confusion Matrix :
#  [[268 100]
#  [ 99 269]]
# Accuracy on test set:    0.7296195652173914
# Sensitivity:    0.7309782608695652 	 Specificity:    0.7282608695652174
#               precision    recall  f1-score   support
#
#            0       0.73      0.73      0.73       368
#            1       0.73      0.73      0.73       368
#
#     accuracy                           0.73       736
#    macro avg       0.73      0.73      0.73       736
# weighted avg       0.73      0.73      0.73       736
#
# Area Under Curve:    0.7296195652173914
# Precision:    0.7289972899728997
#
# Seed   :     0
#
# dbPTM_ANN_program_first_revision0.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5995 - accuracy: 0.6675 - val_loss: 0.5487 - val_accuracy: 0.7107
# Epoch 2/400
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5248 - accuracy: 0.7417 - val_loss: 0.5356 - val_accuracy: 0.7216
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4913 - accuracy: 0.7655 - val_loss: 0.5262 - val_accuracy: 0.7387
# Epoch 4/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4710 - accuracy: 0.7728 - val_loss: 0.5226 - val_accuracy: 0.7403
# Epoch 5/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4518 - accuracy: 0.7913 - val_loss: 0.5111 - val_accuracy: 0.7434
# Epoch 6/400
# 23/23 [==============================] - 0s 18ms/step - loss: 0.4309 - accuracy: 0.8016 - val_loss: 0.5157 - val_accuracy: 0.7449
# Epoch 7/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4189 - accuracy: 0.8108 - val_loss: 0.5139 - val_accuracy: 0.7558
# Epoch 8/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4032 - accuracy: 0.8180 - val_loss: 0.5068 - val_accuracy: 0.7512
# Epoch 9/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3870 - accuracy: 0.8322 - val_loss: 0.5034 - val_accuracy: 0.7589
# Epoch 10/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3713 - accuracy: 0.8381 - val_loss: 0.5067 - val_accuracy: 0.7729
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3586 - accuracy: 0.8478 - val_loss: 0.5126 - val_accuracy: 0.7636
# Epoch 12/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3456 - accuracy: 0.8548 - val_loss: 0.5125 - val_accuracy: 0.7698
# Epoch 13/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3339 - accuracy: 0.8590 - val_loss: 0.5071 - val_accuracy: 0.7481
# Epoch 14/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3170 - accuracy: 0.8720 - val_loss: 0.5134 - val_accuracy: 0.7667
# Epoch 15/400
# 23/23 [==============================] - ETA: 0s - loss: 0.3046 - accuracy: 0.8775
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3046 - accuracy: 0.8775 - val_loss: 0.5186 - val_accuracy: 0.7667
# Matthews Correlation :  0.3922846622181334
# Confusion Matrix :
#  [[243 125]
#  [ 99 269]]
# Accuracy on test set:    0.6956521739130435
# Sensitivity:    0.7309782608695652 	 Specificity:    0.6603260869565217
#               precision    recall  f1-score   support
#
#            0       0.71      0.66      0.68       368
#            1       0.68      0.73      0.71       368
#
#     accuracy                           0.70       736
#    macro avg       0.70      0.70      0.70       736
# weighted avg       0.70      0.70      0.70       736
#
# Area Under Curve:    0.6956521739130435
# Precision:    0.682741116751269
#
# Seed   :     1
#
# dbPTM_ANN_program_first_revision1.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6025 - accuracy: 0.6646 - val_loss: 0.5316 - val_accuracy: 0.7481
# Epoch 2/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.5294 - accuracy: 0.7335 - val_loss: 0.5072 - val_accuracy: 0.7434
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4987 - accuracy: 0.7583 - val_loss: 0.4976 - val_accuracy: 0.7636
# Epoch 4/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4840 - accuracy: 0.7674 - val_loss: 0.4894 - val_accuracy: 0.7683
# Epoch 5/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4610 - accuracy: 0.7843 - val_loss: 0.4909 - val_accuracy: 0.7574
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4428 - accuracy: 0.8002 - val_loss: 0.4894 - val_accuracy: 0.7621
# Epoch 7/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4296 - accuracy: 0.8073 - val_loss: 0.4878 - val_accuracy: 0.7636
# Epoch 8/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4133 - accuracy: 0.8130 - val_loss: 0.4946 - val_accuracy: 0.7589
# Epoch 9/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4022 - accuracy: 0.8300 - val_loss: 0.4879 - val_accuracy: 0.7714
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3895 - accuracy: 0.8308 - val_loss: 0.4864 - val_accuracy: 0.7652
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3694 - accuracy: 0.8460 - val_loss: 0.4926 - val_accuracy: 0.7574
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3631 - accuracy: 0.8519 - val_loss: 0.4903 - val_accuracy: 0.7698
# Epoch 13/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3469 - accuracy: 0.8545 - val_loss: 0.4896 - val_accuracy: 0.7745
# Epoch 14/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3320 - accuracy: 0.8631 - val_loss: 0.4945 - val_accuracy: 0.7605
# Epoch 15/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3248 - accuracy: 0.8694 - val_loss: 0.4958 - val_accuracy: 0.7698
# Epoch 16/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3069 - accuracy: 0.8770 - val_loss: 0.4992 - val_accuracy: 0.7667
# Epoch 17/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2979 - accuracy: 0.8830 - val_loss: 0.5025 - val_accuracy: 0.7729
# Epoch 18/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2744 - accuracy: 0.8906
# Epoch 00018: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2898 - accuracy: 0.8889 - val_loss: 0.5023 - val_accuracy: 0.7698
# Matthews Correlation :  0.3563587055082659
# Confusion Matrix :
#  [[241 127]
#  [110 258]]
# Accuracy on test set:    0.6779891304347826
# Sensitivity:    0.7010869565217391 	 Specificity:    0.654891304347826
#               precision    recall  f1-score   support
#
#            0       0.69      0.65      0.67       368
#            1       0.67      0.70      0.69       368
#
#     accuracy                           0.68       736
#    macro avg       0.68      0.68      0.68       736
# weighted avg       0.68      0.68      0.68       736
#
# Area Under Curve:    0.6779891304347827
# Precision:    0.6701298701298701
#
# Seed   :     2
#
# dbPTM_ANN_program_first_revision2.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6025 - accuracy: 0.6577 - val_loss: 0.5609 - val_accuracy: 0.7247
# Epoch 2/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5311 - accuracy: 0.7299 - val_loss: 0.5247 - val_accuracy: 0.7434
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4947 - accuracy: 0.7581 - val_loss: 0.5105 - val_accuracy: 0.7543
# Epoch 4/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4706 - accuracy: 0.7735 - val_loss: 0.5054 - val_accuracy: 0.7527
# Epoch 5/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4476 - accuracy: 0.7954 - val_loss: 0.4970 - val_accuracy: 0.7652
# Epoch 6/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4296 - accuracy: 0.8084 - val_loss: 0.4925 - val_accuracy: 0.7605
# Epoch 7/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4173 - accuracy: 0.8122 - val_loss: 0.4913 - val_accuracy: 0.7683
# Epoch 8/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3990 - accuracy: 0.8227 - val_loss: 0.4880 - val_accuracy: 0.7760
# Epoch 9/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3881 - accuracy: 0.8369 - val_loss: 0.4890 - val_accuracy: 0.7745
# Epoch 10/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3698 - accuracy: 0.8421 - val_loss: 0.4877 - val_accuracy: 0.7838
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3587 - accuracy: 0.8490 - val_loss: 0.4975 - val_accuracy: 0.7760
# Epoch 12/400
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3441 - accuracy: 0.8569 - val_loss: 0.4894 - val_accuracy: 0.7807
# Epoch 13/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3270 - accuracy: 0.8676 - val_loss: 0.4905 - val_accuracy: 0.7792
# Epoch 14/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3214 - accuracy: 0.8675 - val_loss: 0.4942 - val_accuracy: 0.7807
# Epoch 15/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3433 - accuracy: 0.8594
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3048 - accuracy: 0.8770 - val_loss: 0.4912 - val_accuracy: 0.7745
# Matthews Correlation :  0.391304347826087
# Confusion Matrix :
#  [[256 112]
#  [112 256]]
# Accuracy on test set:    0.6956521739130435
# Sensitivity:    0.6956521739130435 	 Specificity:    0.6956521739130435
#               precision    recall  f1-score   support
#
#            0       0.70      0.70      0.70       368
#            1       0.70      0.70      0.70       368
#
#     accuracy                           0.70       736
#    macro avg       0.70      0.70      0.70       736
# weighted avg       0.70      0.70      0.70       736
#
# Area Under Curve:    0.6956521739130435
# Precision:    0.6956521739130435
#
# Seed   :     3
#
# dbPTM_ANN_program_first_revision3.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.5924 - accuracy: 0.6715 - val_loss: 0.5434 - val_accuracy: 0.7496
# Epoch 2/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.5182 - accuracy: 0.7448 - val_loss: 0.5176 - val_accuracy: 0.7465
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4909 - accuracy: 0.7598 - val_loss: 0.4992 - val_accuracy: 0.7636
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4704 - accuracy: 0.7728 - val_loss: 0.4996 - val_accuracy: 0.7589
# Epoch 5/400
# 23/23 [==============================] - 0s 17ms/step - loss: 0.4509 - accuracy: 0.7909 - val_loss: 0.4912 - val_accuracy: 0.7729
# Epoch 6/400
# 23/23 [==============================] - 0s 18ms/step - loss: 0.4350 - accuracy: 0.8006 - val_loss: 0.4896 - val_accuracy: 0.7683
# Epoch 7/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4235 - accuracy: 0.8066 - val_loss: 0.4819 - val_accuracy: 0.7807
# Epoch 8/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4099 - accuracy: 0.8154 - val_loss: 0.4819 - val_accuracy: 0.7823
# Epoch 9/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3961 - accuracy: 0.8212 - val_loss: 0.4879 - val_accuracy: 0.7869
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3850 - accuracy: 0.8307 - val_loss: 0.4870 - val_accuracy: 0.7683
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3741 - accuracy: 0.8339 - val_loss: 0.4906 - val_accuracy: 0.7714
# Epoch 12/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3673 - accuracy: 0.8400 - val_loss: 0.4893 - val_accuracy: 0.7807
# Epoch 13/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3473 - accuracy: 0.8498 - val_loss: 0.4882 - val_accuracy: 0.7760
# Epoch 14/400
# 19/23 [=======================>......] - ETA: 0s - loss: 0.3318 - accuracy: 0.8612
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3307 - accuracy: 0.8605 - val_loss: 0.5024 - val_accuracy: 0.7652
# Matthews Correlation :  0.41264994703818525
# Confusion Matrix :
#  [[279  89]
#  [128 240]]
# Accuracy on test set:    0.7051630434782609
# Sensitivity:    0.6521739130434783 	 Specificity:    0.7581521739130435
#               precision    recall  f1-score   support
#
#            0       0.69      0.76      0.72       368
#            1       0.73      0.65      0.69       368
#
#     accuracy                           0.71       736
#    macro avg       0.71      0.71      0.70       736
# weighted avg       0.71      0.71      0.70       736
#
# Area Under Curve:    0.7051630434782609
# Precision:    0.729483282674772
#
# Seed   :     4
#
# dbPTM_ANN_program_first_revision4.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 31ms/step - loss: 0.6047 - accuracy: 0.6623 - val_loss: 0.5391 - val_accuracy: 0.7170
# Epoch 2/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5326 - accuracy: 0.7296 - val_loss: 0.5255 - val_accuracy: 0.7294
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4982 - accuracy: 0.7627 - val_loss: 0.5071 - val_accuracy: 0.7465
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4746 - accuracy: 0.7776 - val_loss: 0.5177 - val_accuracy: 0.7387
# Epoch 5/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4579 - accuracy: 0.7859 - val_loss: 0.5035 - val_accuracy: 0.7527
# Epoch 6/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4392 - accuracy: 0.7985 - val_loss: 0.4869 - val_accuracy: 0.7792
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4209 - accuracy: 0.8116 - val_loss: 0.4877 - val_accuracy: 0.7652
# Epoch 8/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4096 - accuracy: 0.8193 - val_loss: 0.4936 - val_accuracy: 0.7574
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3938 - accuracy: 0.8237 - val_loss: 0.5039 - val_accuracy: 0.7589
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3869 - accuracy: 0.8353 - val_loss: 0.4995 - val_accuracy: 0.7543
# Epoch 11/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3623 - accuracy: 0.8516
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3687 - accuracy: 0.8426 - val_loss: 0.4882 - val_accuracy: 0.7714
# Matthews Correlation :  0.437863895364573
# Confusion Matrix :
#  [[257 111]
#  [ 96 272]]
# Accuracy on test set:    0.71875
# Sensitivity:    0.7391304347826086 	 Specificity:    0.6983695652173914
#               precision    recall  f1-score   support
#
#            0       0.73      0.70      0.71       368
#            1       0.71      0.74      0.72       368
#
#     accuracy                           0.72       736
#    macro avg       0.72      0.72      0.72       736
# weighted avg       0.72      0.72      0.72       736
#
# Area Under Curve:    0.7187500000000001
# Precision:    0.7101827676240209
#
# Seed   :     5
#
# dbPTM_ANN_program_first_revision5.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.6112 - accuracy: 0.6452 - val_loss: 0.5404 - val_accuracy: 0.7030
# Epoch 2/400
# 23/23 [==============================] - 0s 17ms/step - loss: 0.5400 - accuracy: 0.7232 - val_loss: 0.5064 - val_accuracy: 0.7543
# Epoch 3/400
# 23/23 [==============================] - 0s 18ms/step - loss: 0.5046 - accuracy: 0.7539 - val_loss: 0.4937 - val_accuracy: 0.7481
# Epoch 4/400
# 23/23 [==============================] - 0s 17ms/step - loss: 0.4843 - accuracy: 0.7750 - val_loss: 0.4842 - val_accuracy: 0.7558
# Epoch 5/400
# 23/23 [==============================] - 1s 23ms/step - loss: 0.4654 - accuracy: 0.7838 - val_loss: 0.4762 - val_accuracy: 0.7589
# Epoch 6/400
# 23/23 [==============================] - 0s 18ms/step - loss: 0.4490 - accuracy: 0.7909 - val_loss: 0.4964 - val_accuracy: 0.7512
# Epoch 7/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4349 - accuracy: 0.8068 - val_loss: 0.4846 - val_accuracy: 0.7574
# Epoch 8/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4181 - accuracy: 0.8125 - val_loss: 0.4824 - val_accuracy: 0.7543
# Epoch 9/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4046 - accuracy: 0.8220 - val_loss: 0.4740 - val_accuracy: 0.7667
# Epoch 10/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3864 - accuracy: 0.8369 - val_loss: 0.4779 - val_accuracy: 0.7698
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3716 - accuracy: 0.8405 - val_loss: 0.4820 - val_accuracy: 0.7605
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3676 - accuracy: 0.8443 - val_loss: 0.4743 - val_accuracy: 0.7558
# Epoch 13/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3482 - accuracy: 0.8585 - val_loss: 0.4822 - val_accuracy: 0.7558
# Epoch 14/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3331 - accuracy: 0.8607 - val_loss: 0.4808 - val_accuracy: 0.7589
# Epoch 15/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2990 - accuracy: 0.8867
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3243 - accuracy: 0.8714 - val_loss: 0.4811 - val_accuracy: 0.7605
# Matthews Correlation :  0.4213216717862875
# Confusion Matrix :
#  [[257 111]
#  [102 266]]
# Accuracy on test set:    0.7105978260869565
# Sensitivity:    0.7228260869565217 	 Specificity:    0.6983695652173914
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       368
#            1       0.71      0.72      0.71       368
#
#     accuracy                           0.71       736
#    macro avg       0.71      0.71      0.71       736
# weighted avg       0.71      0.71      0.71       736
#
# Area Under Curve:    0.7105978260869565
# Precision:    0.7055702917771883
#
# Seed   :     6
#
# dbPTM_ANN_program_first_revision6.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 22ms/step - loss: 0.6031 - accuracy: 0.6672 - val_loss: 0.5327 - val_accuracy: 0.7434
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5263 - accuracy: 0.7387 - val_loss: 0.5203 - val_accuracy: 0.7481
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4955 - accuracy: 0.7541 - val_loss: 0.4995 - val_accuracy: 0.7512
# Epoch 4/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4749 - accuracy: 0.7698 - val_loss: 0.4954 - val_accuracy: 0.7574
# Epoch 5/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4520 - accuracy: 0.7876 - val_loss: 0.4902 - val_accuracy: 0.7652
# Epoch 6/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4292 - accuracy: 0.8059 - val_loss: 0.4963 - val_accuracy: 0.7760
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4141 - accuracy: 0.8167 - val_loss: 0.4816 - val_accuracy: 0.7667
# Epoch 8/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3966 - accuracy: 0.8237 - val_loss: 0.4817 - val_accuracy: 0.7698
# Epoch 9/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3821 - accuracy: 0.8294 - val_loss: 0.4918 - val_accuracy: 0.7683
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3665 - accuracy: 0.8433 - val_loss: 0.4904 - val_accuracy: 0.7652
# Epoch 11/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3661 - accuracy: 0.8359
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3477 - accuracy: 0.8567 - val_loss: 0.4907 - val_accuracy: 0.7729
# Matthews Correlation :  0.46543235705168556
# Confusion Matrix :
#  [[259 109]
#  [ 88 280]]
# Accuracy on test set:    0.7323369565217391
# Sensitivity:    0.7608695652173914 	 Specificity:    0.7038043478260869
#               precision    recall  f1-score   support
#
#            0       0.75      0.70      0.72       368
#            1       0.72      0.76      0.74       368
#
#     accuracy                           0.73       736
#    macro avg       0.73      0.73      0.73       736
# weighted avg       0.73      0.73      0.73       736
#
# Area Under Curve:    0.7323369565217391
# Precision:    0.7197943444730077
#
# Seed   :     7
#
# dbPTM_ANN_program_first_revision7.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 23ms/step - loss: 0.6122 - accuracy: 0.6356 - val_loss: 0.5470 - val_accuracy: 0.7014
# Epoch 2/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.5256 - accuracy: 0.7322 - val_loss: 0.5255 - val_accuracy: 0.7201
# Epoch 3/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4963 - accuracy: 0.7629 - val_loss: 0.5068 - val_accuracy: 0.7387
# Epoch 4/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4682 - accuracy: 0.7769 - val_loss: 0.4999 - val_accuracy: 0.7449
# Epoch 5/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4489 - accuracy: 0.7952 - val_loss: 0.4981 - val_accuracy: 0.7449
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4272 - accuracy: 0.8072 - val_loss: 0.5011 - val_accuracy: 0.7434
# Epoch 7/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4143 - accuracy: 0.8170 - val_loss: 0.4885 - val_accuracy: 0.7605
# Epoch 8/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4005 - accuracy: 0.8239 - val_loss: 0.4871 - val_accuracy: 0.7558
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3856 - accuracy: 0.8331 - val_loss: 0.4869 - val_accuracy: 0.7574
# Epoch 10/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3692 - accuracy: 0.8479 - val_loss: 0.4840 - val_accuracy: 0.7589
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3549 - accuracy: 0.8524 - val_loss: 0.4898 - val_accuracy: 0.7543
# Epoch 12/400
# 22/23 [===========================>..] - ETA: 0s - loss: 0.3397 - accuracy: 0.8587
# Epoch 00012: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3406 - accuracy: 0.8585 - val_loss: 0.5041 - val_accuracy: 0.7512
# Matthews Correlation :  0.4317850280564829
# Confusion Matrix :
#  [[221 147]
#  [ 66 302]]
# Accuracy on test set:    0.7105978260869565
# Sensitivity:    0.8206521739130435 	 Specificity:    0.6005434782608695
#               precision    recall  f1-score   support
#
#            0       0.77      0.60      0.67       368
#            1       0.67      0.82      0.74       368
#
#     accuracy                           0.71       736
#    macro avg       0.72      0.71      0.71       736
# weighted avg       0.72      0.71      0.71       736
#
# Area Under Curve:    0.7105978260869565
# Precision:    0.6726057906458798
#
# Seed   :     8
#
# dbPTM_ANN_program_first_revision8.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 22ms/step - loss: 0.6066 - accuracy: 0.6636 - val_loss: 0.5682 - val_accuracy: 0.7216
# Epoch 2/400
# 23/23 [==============================] - 0s 11ms/step - loss: 0.5320 - accuracy: 0.7327 - val_loss: 0.5297 - val_accuracy: 0.7434
# Epoch 3/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4990 - accuracy: 0.7586 - val_loss: 0.5138 - val_accuracy: 0.7652
# Epoch 4/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4803 - accuracy: 0.7740 - val_loss: 0.5086 - val_accuracy: 0.7589
# Epoch 5/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4635 - accuracy: 0.7857 - val_loss: 0.5100 - val_accuracy: 0.7636
# Epoch 6/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4426 - accuracy: 0.7987 - val_loss: 0.5008 - val_accuracy: 0.7745
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4301 - accuracy: 0.8034 - val_loss: 0.5040 - val_accuracy: 0.7745
# Epoch 8/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4104 - accuracy: 0.8196 - val_loss: 0.4956 - val_accuracy: 0.7869
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3957 - accuracy: 0.8277 - val_loss: 0.4989 - val_accuracy: 0.7760
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3887 - accuracy: 0.8332 - val_loss: 0.4944 - val_accuracy: 0.7714
# Epoch 11/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3752 - accuracy: 0.8379 - val_loss: 0.5003 - val_accuracy: 0.7776
# Epoch 12/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3596 - accuracy: 0.8514 - val_loss: 0.4979 - val_accuracy: 0.7760
# Epoch 13/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3612 - accuracy: 0.8633
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3468 - accuracy: 0.8576 - val_loss: 0.5132 - val_accuracy: 0.7574
# Matthews Correlation :  0.4258109729791849
# Confusion Matrix :
#  [[227 141]
#  [ 73 295]]
# Accuracy on test set:    0.7092391304347826
# Sensitivity:    0.8016304347826086 	 Specificity:    0.6168478260869565
#               precision    recall  f1-score   support
#
#            0       0.76      0.62      0.68       368
#            1       0.68      0.80      0.73       368
#
#     accuracy                           0.71       736
#    macro avg       0.72      0.71      0.71       736
# weighted avg       0.72      0.71      0.71       736
#
# Area Under Curve:    0.7092391304347826
# Precision:    0.676605504587156
#
# Seed   :     9
#
# dbPTM_ANN_program_first_revision9.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.6025 - accuracy: 0.6598 - val_loss: 0.5420 - val_accuracy: 0.7263
# Epoch 2/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5354 - accuracy: 0.7322 - val_loss: 0.5286 - val_accuracy: 0.7309
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5017 - accuracy: 0.7555 - val_loss: 0.5172 - val_accuracy: 0.7434
# Epoch 4/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4795 - accuracy: 0.7752 - val_loss: 0.5185 - val_accuracy: 0.7527
# Epoch 5/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4623 - accuracy: 0.7859 - val_loss: 0.5153 - val_accuracy: 0.7449
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4398 - accuracy: 0.7996 - val_loss: 0.5066 - val_accuracy: 0.7527
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4270 - accuracy: 0.8070 - val_loss: 0.5088 - val_accuracy: 0.7481
# Epoch 8/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4157 - accuracy: 0.8120 - val_loss: 0.5000 - val_accuracy: 0.7558
# Epoch 9/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3935 - accuracy: 0.8288 - val_loss: 0.5065 - val_accuracy: 0.7714
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3843 - accuracy: 0.8315 - val_loss: 0.5053 - val_accuracy: 0.7621
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3653 - accuracy: 0.8471 - val_loss: 0.5153 - val_accuracy: 0.7589
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3511 - accuracy: 0.8488 - val_loss: 0.5060 - val_accuracy: 0.7667
# Epoch 13/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3369 - accuracy: 0.8635 - val_loss: 0.5122 - val_accuracy: 0.7729
# Epoch 14/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3255 - accuracy: 0.8666 - val_loss: 0.5178 - val_accuracy: 0.7714
# Epoch 15/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3139 - accuracy: 0.8782 - val_loss: 0.5222 - val_accuracy: 0.7729
# Epoch 16/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.3075 - accuracy: 0.8827 - val_loss: 0.5264 - val_accuracy: 0.7745
# Epoch 17/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.2908 - accuracy: 0.8884 - val_loss: 0.5315 - val_accuracy: 0.7792
# Epoch 18/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2766 - accuracy: 0.8946 - val_loss: 0.5379 - val_accuracy: 0.7652
# Epoch 19/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2700 - accuracy: 0.8958 - val_loss: 0.5431 - val_accuracy: 0.7574
# Epoch 20/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2637 - accuracy: 0.9008 - val_loss: 0.5394 - val_accuracy: 0.7714
# Epoch 21/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2479 - accuracy: 0.9105 - val_loss: 0.5506 - val_accuracy: 0.7652
# Epoch 22/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2106 - accuracy: 0.9375
# Epoch 00022: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2393 - accuracy: 0.9141 - val_loss: 0.5564 - val_accuracy: 0.7621
# Matthews Correlation :  0.3881694399461172
# Confusion Matrix :
#  [[275  93]
#  [133 235]]
# Accuracy on test set:    0.6929347826086957
# Sensitivity:    0.6385869565217391 	 Specificity:    0.7472826086956522
#               precision    recall  f1-score   support
#
#            0       0.67      0.75      0.71       368
#            1       0.72      0.64      0.68       368
#
#     accuracy                           0.69       736
#    macro avg       0.70      0.69      0.69       736
# weighted avg       0.70      0.69      0.69       736
#
# Area Under Curve:    0.6929347826086957
# Precision:    0.7164634146341463
#
# Seed   :     10
#
# dbPTM_ANN_program_first_revision10.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 23ms/step - loss: 0.6044 - accuracy: 0.6613 - val_loss: 0.5617 - val_accuracy: 0.6890
# Epoch 2/400
# 23/23 [==============================] - 0s 12ms/step - loss: 0.5298 - accuracy: 0.7386 - val_loss: 0.5201 - val_accuracy: 0.7418
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5025 - accuracy: 0.7558 - val_loss: 0.5059 - val_accuracy: 0.7512
# Epoch 4/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4796 - accuracy: 0.7690 - val_loss: 0.4966 - val_accuracy: 0.7403
# Epoch 5/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4636 - accuracy: 0.7814 - val_loss: 0.4966 - val_accuracy: 0.7418
# Epoch 6/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4475 - accuracy: 0.7888 - val_loss: 0.4887 - val_accuracy: 0.7729
# Epoch 7/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4300 - accuracy: 0.8018 - val_loss: 0.4827 - val_accuracy: 0.7543
# Epoch 8/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4181 - accuracy: 0.8160 - val_loss: 0.4846 - val_accuracy: 0.7652
# Epoch 9/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4016 - accuracy: 0.8258 - val_loss: 0.4802 - val_accuracy: 0.7698
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3868 - accuracy: 0.8343 - val_loss: 0.4839 - val_accuracy: 0.7729
# Epoch 11/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3739 - accuracy: 0.8594
# Epoch 00011: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3770 - accuracy: 0.8374 - val_loss: 0.4999 - val_accuracy: 0.7527
# Matthews Correlation :  0.3995491107323966
# Confusion Matrix :
#  [[287  81]
#  [142 226]]
# Accuracy on test set:    0.6970108695652174
# Sensitivity:    0.6141304347826086 	 Specificity:    0.779891304347826
#               precision    recall  f1-score   support
#
#            0       0.67      0.78      0.72       368
#            1       0.74      0.61      0.67       368
#
#     accuracy                           0.70       736
#    macro avg       0.70      0.70      0.69       736
# weighted avg       0.70      0.70      0.69       736
#
# Area Under Curve:    0.6970108695652174
# Precision:    0.7361563517915309
#
# Seed   :     11
#
# dbPTM_ANN_program_first_revision11.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 21ms/step - loss: 0.6112 - accuracy: 0.6470 - val_loss: 0.5626 - val_accuracy: 0.7092
# Epoch 2/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5416 - accuracy: 0.7311 - val_loss: 0.5185 - val_accuracy: 0.7387
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5006 - accuracy: 0.7551 - val_loss: 0.5023 - val_accuracy: 0.7512
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4764 - accuracy: 0.7735 - val_loss: 0.4985 - val_accuracy: 0.7449
# Epoch 5/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4529 - accuracy: 0.7902 - val_loss: 0.4949 - val_accuracy: 0.7589
# Epoch 6/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4400 - accuracy: 0.8004 - val_loss: 0.4944 - val_accuracy: 0.7652
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4267 - accuracy: 0.8068 - val_loss: 0.4842 - val_accuracy: 0.7652
# Epoch 8/400
# 23/23 [==============================] - 0s 11ms/step - loss: 0.4044 - accuracy: 0.8175 - val_loss: 0.4807 - val_accuracy: 0.7667
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3882 - accuracy: 0.8365 - val_loss: 0.4791 - val_accuracy: 0.7652
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3789 - accuracy: 0.8350 - val_loss: 0.4809 - val_accuracy: 0.7667
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3588 - accuracy: 0.8521 - val_loss: 0.4784 - val_accuracy: 0.7667
# Epoch 12/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3443 - accuracy: 0.8528 - val_loss: 0.4787 - val_accuracy: 0.7667
# Epoch 13/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3708 - accuracy: 0.8438
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3385 - accuracy: 0.8576 - val_loss: 0.4738 - val_accuracy: 0.7667
# Matthews Correlation :  0.3837128834468253
# Confusion Matrix :
#  [[278  90]
#  [138 230]]
# Accuracy on test set:    0.6902173913043478
# Sensitivity:    0.625 	 Specificity:    0.7554347826086957
#               precision    recall  f1-score   support
#
#            0       0.67      0.76      0.71       368
#            1       0.72      0.62      0.67       368
#
#     accuracy                           0.69       736
#    macro avg       0.69      0.69      0.69       736
# weighted avg       0.69      0.69      0.69       736
#
# Area Under Curve:    0.6902173913043478
# Precision:    0.71875
#
# Seed   :     12
#
# dbPTM_ANN_program_first_revision12.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6027 - accuracy: 0.6663 - val_loss: 0.5435 - val_accuracy: 0.7278
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5240 - accuracy: 0.7481 - val_loss: 0.5144 - val_accuracy: 0.7512
# Epoch 3/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4916 - accuracy: 0.7608 - val_loss: 0.4995 - val_accuracy: 0.7652
# Epoch 4/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4675 - accuracy: 0.7814 - val_loss: 0.4892 - val_accuracy: 0.7745
# Epoch 5/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4505 - accuracy: 0.7876 - val_loss: 0.4895 - val_accuracy: 0.7652
# Epoch 6/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4321 - accuracy: 0.8006 - val_loss: 0.4896 - val_accuracy: 0.7527
# Epoch 7/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4126 - accuracy: 0.8173 - val_loss: 0.4858 - val_accuracy: 0.7698
# Epoch 8/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4010 - accuracy: 0.8217 - val_loss: 0.4901 - val_accuracy: 0.7792
# Epoch 9/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3865 - accuracy: 0.8272 - val_loss: 0.4888 - val_accuracy: 0.7714
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3708 - accuracy: 0.8436 - val_loss: 0.4964 - val_accuracy: 0.7636
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3583 - accuracy: 0.8481 - val_loss: 0.4923 - val_accuracy: 0.7792
# Epoch 12/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.3429 - accuracy: 0.8569 - val_loss: 0.4981 - val_accuracy: 0.7807
# Epoch 13/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3348 - accuracy: 0.8625 - val_loss: 0.4979 - val_accuracy: 0.7776
# Epoch 14/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.3176 - accuracy: 0.8714 - val_loss: 0.5066 - val_accuracy: 0.7869
# Epoch 15/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3076 - accuracy: 0.8745 - val_loss: 0.5013 - val_accuracy: 0.7729
# Epoch 16/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2951 - accuracy: 0.8863 - val_loss: 0.5189 - val_accuracy: 0.7729
# Epoch 17/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2871 - accuracy: 0.8856 - val_loss: 0.5131 - val_accuracy: 0.7807
# Epoch 18/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2702 - accuracy: 0.8963 - val_loss: 0.5195 - val_accuracy: 0.7776
# Epoch 19/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2344 - accuracy: 0.9219
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2619 - accuracy: 0.8970 - val_loss: 0.5192 - val_accuracy: 0.7745
# Matthews Correlation :  0.3574235195493492
# Confusion Matrix :
#  [[221 147]
#  [ 91 277]]
# Accuracy on test set:    0.6766304347826086
# Sensitivity:    0.7527173913043478 	 Specificity:    0.6005434782608695
#               precision    recall  f1-score   support
#
#            0       0.71      0.60      0.65       368
#            1       0.65      0.75      0.70       368
#
#     accuracy                           0.68       736
#    macro avg       0.68      0.68      0.67       736
# weighted avg       0.68      0.68      0.67       736
#
# Area Under Curve:    0.6766304347826086
# Precision:    0.6533018867924528
#
# Seed   :     13
#
# dbPTM_ANN_program_first_revision13.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 22ms/step - loss: 0.5930 - accuracy: 0.6670 - val_loss: 0.5875 - val_accuracy: 0.6921
# Epoch 2/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5161 - accuracy: 0.7456 - val_loss: 0.5625 - val_accuracy: 0.6983
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4790 - accuracy: 0.7717 - val_loss: 0.5487 - val_accuracy: 0.7185
# Epoch 4/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4605 - accuracy: 0.7861 - val_loss: 0.5367 - val_accuracy: 0.7278
# Epoch 5/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4410 - accuracy: 0.7911 - val_loss: 0.5305 - val_accuracy: 0.7418
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4248 - accuracy: 0.8039 - val_loss: 0.5329 - val_accuracy: 0.7372
# Epoch 7/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.4060 - accuracy: 0.8208 - val_loss: 0.5331 - val_accuracy: 0.7449
# Epoch 8/400
# 23/23 [==============================] - 0s 13ms/step - loss: 0.3928 - accuracy: 0.8251 - val_loss: 0.5205 - val_accuracy: 0.7667
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3799 - accuracy: 0.8329 - val_loss: 0.5265 - val_accuracy: 0.7527
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3633 - accuracy: 0.8457 - val_loss: 0.5236 - val_accuracy: 0.7621
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3516 - accuracy: 0.8500 - val_loss: 0.5191 - val_accuracy: 0.7574
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3365 - accuracy: 0.8578 - val_loss: 0.5225 - val_accuracy: 0.7558
# Epoch 13/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3601 - accuracy: 0.8359
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3253 - accuracy: 0.8647 - val_loss: 0.5372 - val_accuracy: 0.7496
# Matthews Correlation :  0.48017705765753393
# Confusion Matrix :
#  [[246 122]
#  [ 71 297]]
# Accuracy on test set:    0.7377717391304348
# Sensitivity:    0.8070652173913043 	 Specificity:    0.6684782608695652
#               precision    recall  f1-score   support
#
#            0       0.78      0.67      0.72       368
#            1       0.71      0.81      0.75       368
#
#     accuracy                           0.74       736
#    macro avg       0.74      0.74      0.74       736
# weighted avg       0.74      0.74      0.74       736
#
# Area Under Curve:    0.7377717391304347
# Precision:    0.7088305489260143
#
# Seed   :     14
#
# dbPTM_ANN_program_first_revision14.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.6021 - accuracy: 0.6623 - val_loss: 0.5628 - val_accuracy: 0.6952
# Epoch 2/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.5290 - accuracy: 0.7360 - val_loss: 0.5266 - val_accuracy: 0.7154
# Epoch 3/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4928 - accuracy: 0.7627 - val_loss: 0.5150 - val_accuracy: 0.7247
# Epoch 4/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4697 - accuracy: 0.7788 - val_loss: 0.5104 - val_accuracy: 0.7341
# Epoch 5/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4487 - accuracy: 0.7923 - val_loss: 0.5064 - val_accuracy: 0.7372
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4297 - accuracy: 0.8106 - val_loss: 0.5074 - val_accuracy: 0.7325
# Epoch 7/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4152 - accuracy: 0.8142 - val_loss: 0.5068 - val_accuracy: 0.7325
# Epoch 8/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4005 - accuracy: 0.8288 - val_loss: 0.5061 - val_accuracy: 0.7434
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3846 - accuracy: 0.8377 - val_loss: 0.5088 - val_accuracy: 0.7387
# Epoch 10/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3720 - accuracy: 0.8396 - val_loss: 0.5071 - val_accuracy: 0.7496
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3568 - accuracy: 0.8519 - val_loss: 0.5215 - val_accuracy: 0.7294
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3433 - accuracy: 0.8564 - val_loss: 0.5285 - val_accuracy: 0.7465
# Epoch 13/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3348 - accuracy: 0.8630 - val_loss: 0.5211 - val_accuracy: 0.7434
# Epoch 14/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3164 - accuracy: 0.8742 - val_loss: 0.5238 - val_accuracy: 0.7449
# Epoch 15/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2818 - accuracy: 0.8984
# Epoch 00015: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3036 - accuracy: 0.8792 - val_loss: 0.5357 - val_accuracy: 0.7341
# Matthews Correlation :  0.38339147191689704
# Confusion Matrix :
#  [[261 107]
#  [120 248]]
# Accuracy on test set:    0.6915760869565217
# Sensitivity:    0.6739130434782609 	 Specificity:    0.7092391304347826
#               precision    recall  f1-score   support
#
#            0       0.69      0.71      0.70       368
#            1       0.70      0.67      0.69       368
#
#     accuracy                           0.69       736
#    macro avg       0.69      0.69      0.69       736
# weighted avg       0.69      0.69      0.69       736
#
# Area Under Curve:    0.6915760869565216
# Precision:    0.6985915492957746
#
# Seed   :     15
#
# dbPTM_ANN_program_first_revision15.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 19ms/step - loss: 0.5863 - accuracy: 0.6722 - val_loss: 0.5856 - val_accuracy: 0.6952
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5201 - accuracy: 0.7451 - val_loss: 0.5547 - val_accuracy: 0.7216
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4852 - accuracy: 0.7702 - val_loss: 0.5409 - val_accuracy: 0.7356
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4602 - accuracy: 0.7818 - val_loss: 0.5333 - val_accuracy: 0.7356
# Epoch 5/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4419 - accuracy: 0.7907 - val_loss: 0.5287 - val_accuracy: 0.7434
# Epoch 6/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4309 - accuracy: 0.8051 - val_loss: 0.5380 - val_accuracy: 0.7481
# Epoch 7/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4120 - accuracy: 0.8125 - val_loss: 0.5198 - val_accuracy: 0.7574
# Epoch 8/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3903 - accuracy: 0.8317 - val_loss: 0.5128 - val_accuracy: 0.7621
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3827 - accuracy: 0.8322 - val_loss: 0.5128 - val_accuracy: 0.7574
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3637 - accuracy: 0.8459 - val_loss: 0.5285 - val_accuracy: 0.7621
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3533 - accuracy: 0.8509 - val_loss: 0.5229 - val_accuracy: 0.7621
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3354 - accuracy: 0.8616 - val_loss: 0.5207 - val_accuracy: 0.7589
# Epoch 13/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2827 - accuracy: 0.8984
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3244 - accuracy: 0.8697 - val_loss: 0.5180 - val_accuracy: 0.7605
# Matthews Correlation :  0.5002660439456338
# Confusion Matrix :
#  [[282  86]
#  [ 98 270]]
# Accuracy on test set:    0.75
# Sensitivity:    0.7336956521739131 	 Specificity:    0.7663043478260869
#               precision    recall  f1-score   support
#
#            0       0.74      0.77      0.75       368
#            1       0.76      0.73      0.75       368
#
#     accuracy                           0.75       736
#    macro avg       0.75      0.75      0.75       736
# weighted avg       0.75      0.75      0.75       736
#
# Area Under Curve:    0.75
# Precision:    0.7584269662921348
#
# Seed   :     16
#
# dbPTM_ANN_program_first_revision16.h5
# Epoch 1/400
# ...
#    macro avg       0.70      0.70      0.70       736
# weighted avg       0.70      0.70      0.70       736
#
# Area Under Curve:    0.6956521739130433
# Precision:    0.7011173184357542
#
# Seed   :     94
#
# dbPTM_ANN_program_first_revision94.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 24ms/step - loss: 0.6065 - accuracy: 0.6541 - val_loss: 0.5554 - val_accuracy: 0.7232
# Epoch 2/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5293 - accuracy: 0.7372 - val_loss: 0.5378 - val_accuracy: 0.7496
# Epoch 3/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4951 - accuracy: 0.7607 - val_loss: 0.5239 - val_accuracy: 0.7589
# Epoch 4/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4710 - accuracy: 0.7747 - val_loss: 0.5123 - val_accuracy: 0.7558
# Epoch 5/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4563 - accuracy: 0.7864 - val_loss: 0.5172 - val_accuracy: 0.7574
# Epoch 6/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4400 - accuracy: 0.8011 - val_loss: 0.5093 - val_accuracy: 0.7636
# Epoch 7/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4190 - accuracy: 0.8186 - val_loss: 0.5171 - val_accuracy: 0.7558
# Epoch 8/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.4038 - accuracy: 0.8244 - val_loss: 0.5080 - val_accuracy: 0.7605
# Epoch 9/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3952 - accuracy: 0.8224 - val_loss: 0.5055 - val_accuracy: 0.7760
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3781 - accuracy: 0.8402 - val_loss: 0.5101 - val_accuracy: 0.7667
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3669 - accuracy: 0.8436 - val_loss: 0.5140 - val_accuracy: 0.7621
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3469 - accuracy: 0.8581 - val_loss: 0.5099 - val_accuracy: 0.7745
# Epoch 13/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3368 - accuracy: 0.8625 - val_loss: 0.5223 - val_accuracy: 0.7652
# Epoch 14/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3241 - accuracy: 0.8516
# Epoch 00014: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3220 - accuracy: 0.8685 - val_loss: 0.5215 - val_accuracy: 0.7512
# Matthews Correlation :  0.4431327942258436
# Confusion Matrix :
#  [[260 108]
#  [ 97 271]]
# Accuracy on test set:    0.7214673913043478
# Sensitivity:    0.7364130434782609 	 Specificity:    0.7065217391304348
#               precision    recall  f1-score   support
#
#            0       0.73      0.71      0.72       368
#            1       0.72      0.74      0.73       368
#
#     accuracy                           0.72       736
#    macro avg       0.72      0.72      0.72       736
# weighted avg       0.72      0.72      0.72       736
#
# Area Under Curve:    0.7214673913043478
# Precision:    0.7150395778364116
#
# Seed   :     95
#
# dbPTM_ANN_program_first_revision95.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 21ms/step - loss: 0.5947 - accuracy: 0.6746 - val_loss: 0.5434 - val_accuracy: 0.7216
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5225 - accuracy: 0.7462 - val_loss: 0.5240 - val_accuracy: 0.7372
# Epoch 3/400
# 23/23 [==============================] - 0s 9ms/step - loss: 0.4965 - accuracy: 0.7612 - val_loss: 0.4999 - val_accuracy: 0.7621
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4717 - accuracy: 0.7795 - val_loss: 0.4997 - val_accuracy: 0.7589
# Epoch 5/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4514 - accuracy: 0.7906 - val_loss: 0.4921 - val_accuracy: 0.7714
# Epoch 6/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4345 - accuracy: 0.7996 - val_loss: 0.4882 - val_accuracy: 0.7760
# Epoch 7/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4206 - accuracy: 0.8087 - val_loss: 0.4867 - val_accuracy: 0.7838
# Epoch 8/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4035 - accuracy: 0.8206 - val_loss: 0.4813 - val_accuracy: 0.7854
# Epoch 9/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3850 - accuracy: 0.8336 - val_loss: 0.4802 - val_accuracy: 0.7776
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3743 - accuracy: 0.8391 - val_loss: 0.4793 - val_accuracy: 0.7823
# Epoch 11/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3648 - accuracy: 0.8429 - val_loss: 0.4846 - val_accuracy: 0.7869
# Epoch 12/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3487 - accuracy: 0.8536 - val_loss: 0.4820 - val_accuracy: 0.7807
# Epoch 13/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3369 - accuracy: 0.8607 - val_loss: 0.4792 - val_accuracy: 0.7792
# Epoch 14/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3241 - accuracy: 0.8702 - val_loss: 0.4820 - val_accuracy: 0.7885
# Epoch 15/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3112 - accuracy: 0.8799 - val_loss: 0.4884 - val_accuracy: 0.7683
# Epoch 16/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3043 - accuracy: 0.8759 - val_loss: 0.4978 - val_accuracy: 0.7714
# Epoch 17/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2927 - accuracy: 0.8849 - val_loss: 0.4905 - val_accuracy: 0.7885
# Epoch 18/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2826 - accuracy: 0.8896 - val_loss: 0.4909 - val_accuracy: 0.7838
# Epoch 19/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2514 - accuracy: 0.9102
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2690 - accuracy: 0.8920 - val_loss: 0.4927 - val_accuracy: 0.7792
# Matthews Correlation :  0.38154079843117505
# Confusion Matrix :
#  [[240 128]
#  [100 268]]
# Accuracy on test set:    0.6902173913043478
# Sensitivity:    0.7282608695652174 	 Specificity:    0.6521739130434783
#               precision    recall  f1-score   support
#
#            0       0.71      0.65      0.68       368
#            1       0.68      0.73      0.70       368
#
#     accuracy                           0.69       736
#    macro avg       0.69      0.69      0.69       736
# weighted avg       0.69      0.69      0.69       736
#
# Area Under Curve:    0.6902173913043478
# Precision:    0.6767676767676768
#
# Seed   :     96
#
# dbPTM_ANN_program_first_revision96.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 20ms/step - loss: 0.5974 - accuracy: 0.6646 - val_loss: 0.5295 - val_accuracy: 0.7341
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5277 - accuracy: 0.7356 - val_loss: 0.5032 - val_accuracy: 0.7683
# Epoch 3/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5007 - accuracy: 0.7560 - val_loss: 0.4896 - val_accuracy: 0.7729
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4778 - accuracy: 0.7745 - val_loss: 0.4800 - val_accuracy: 0.7729
# Epoch 5/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4571 - accuracy: 0.7840 - val_loss: 0.4724 - val_accuracy: 0.7760
# Epoch 6/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.4394 - accuracy: 0.7987 - val_loss: 0.4724 - val_accuracy: 0.7869
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4234 - accuracy: 0.8072 - val_loss: 0.4801 - val_accuracy: 0.7792
# Epoch 8/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4059 - accuracy: 0.8180 - val_loss: 0.4724 - val_accuracy: 0.7900
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3923 - accuracy: 0.8277 - val_loss: 0.4690 - val_accuracy: 0.7729
# Epoch 10/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3789 - accuracy: 0.8343 - val_loss: 0.4783 - val_accuracy: 0.7807
# Epoch 11/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3642 - accuracy: 0.8445 - val_loss: 0.4895 - val_accuracy: 0.7698
# Epoch 12/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3530 - accuracy: 0.8497 - val_loss: 0.4842 - val_accuracy: 0.7776
# Epoch 13/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.3559 - accuracy: 0.8555
# Epoch 00013: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3362 - accuracy: 0.8640 - val_loss: 0.4729 - val_accuracy: 0.7900
# Matthews Correlation :  0.4268968871698783
# Confusion Matrix :
#  [[256 112]
#  [ 99 269]]
# Accuracy on test set:    0.7133152173913043
# Sensitivity:    0.7309782608695652 	 Specificity:    0.6956521739130435
#               precision    recall  f1-score   support
#
#            0       0.72      0.70      0.71       368
#            1       0.71      0.73      0.72       368
#
#     accuracy                           0.71       736
#    macro avg       0.71      0.71      0.71       736
# weighted avg       0.71      0.71      0.71       736
#
# Area Under Curve:    0.7133152173913043
# Precision:    0.7060367454068242
#
# Seed   :     97
#
# dbPTM_ANN_program_first_revision97.h5
# Epoch 1/400
# 23/23 [==============================] - 1s 32ms/step - loss: 0.6057 - accuracy: 0.6535 - val_loss: 0.5551 - val_accuracy: 0.7294
# Epoch 2/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.5311 - accuracy: 0.7363 - val_loss: 0.5215 - val_accuracy: 0.7481
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5021 - accuracy: 0.7525 - val_loss: 0.5141 - val_accuracy: 0.7589
# Epoch 4/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4790 - accuracy: 0.7722 - val_loss: 0.4980 - val_accuracy: 0.7574
# Epoch 5/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4647 - accuracy: 0.7821 - val_loss: 0.4942 - val_accuracy: 0.7636
# Epoch 6/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4463 - accuracy: 0.7925 - val_loss: 0.4913 - val_accuracy: 0.7714
# Epoch 7/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4321 - accuracy: 0.7996 - val_loss: 0.4938 - val_accuracy: 0.7698
# Epoch 8/400
# 23/23 [==============================] - 0s 8ms/step - loss: 0.4140 - accuracy: 0.8158 - val_loss: 0.4934 - val_accuracy: 0.7729
# Epoch 9/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3996 - accuracy: 0.8210 - val_loss: 0.4894 - val_accuracy: 0.7729
# Epoch 10/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3799 - accuracy: 0.8386 - val_loss: 0.4874 - val_accuracy: 0.7838
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3761 - accuracy: 0.8383 - val_loss: 0.4982 - val_accuracy: 0.7667
# Epoch 12/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3590 - accuracy: 0.8476 - val_loss: 0.5004 - val_accuracy: 0.7605
# Epoch 13/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3455 - accuracy: 0.8542 - val_loss: 0.4923 - val_accuracy: 0.7792
# Epoch 14/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3350 - accuracy: 0.8669 - val_loss: 0.4874 - val_accuracy: 0.7916
# Epoch 15/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3234 - accuracy: 0.8716 - val_loss: 0.4964 - val_accuracy: 0.7745
# Epoch 16/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3099 - accuracy: 0.8778 - val_loss: 0.4949 - val_accuracy: 0.7885
# Epoch 17/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.2989 - accuracy: 0.8861 - val_loss: 0.4972 - val_accuracy: 0.7807
# Epoch 18/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.2849 - accuracy: 0.8894 - val_loss: 0.5032 - val_accuracy: 0.7714
# Epoch 19/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2739 - accuracy: 0.8945
# Epoch 00019: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2809 - accuracy: 0.8834 - val_loss: 0.5036 - val_accuracy: 0.7776
# Matthews Correlation :  0.39999000453960337
# Confusion Matrix :
#  [[248 120]
#  [101 267]]
# Accuracy on test set:    0.6997282608695652
# Sensitivity:    0.7255434782608695 	 Specificity:    0.6739130434782609
#               precision    recall  f1-score   support
#
#            0       0.71      0.67      0.69       368
#            1       0.69      0.73      0.71       368
#
#     accuracy                           0.70       736
#    macro avg       0.70      0.70      0.70       736
# weighted avg       0.70      0.70      0.70       736
#
# Area Under Curve:    0.6997282608695652
# Precision:    0.689922480620155
#
# Seed   :     98
#
# dbPTM_ANN_program_first_revision98.h5
# Epoch 1/400
# 23/23 [==============================] - 0s 19ms/step - loss: 0.6111 - accuracy: 0.6509 - val_loss: 0.5576 - val_accuracy: 0.7076
# Epoch 2/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5394 - accuracy: 0.7282 - val_loss: 0.5297 - val_accuracy: 0.7309
# Epoch 3/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.5037 - accuracy: 0.7562 - val_loss: 0.5029 - val_accuracy: 0.7465
# Epoch 4/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.4816 - accuracy: 0.7710 - val_loss: 0.4889 - val_accuracy: 0.7605
# Epoch 5/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4612 - accuracy: 0.7838 - val_loss: 0.4803 - val_accuracy: 0.7496
# Epoch 6/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.4453 - accuracy: 0.7930 - val_loss: 0.4761 - val_accuracy: 0.7589
# Epoch 7/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4336 - accuracy: 0.8013 - val_loss: 0.4705 - val_accuracy: 0.7667
# Epoch 8/400
# 23/23 [==============================] - 0s 10ms/step - loss: 0.4168 - accuracy: 0.8116 - val_loss: 0.4705 - val_accuracy: 0.7714
# Epoch 9/400
# 23/23 [==============================] - 0s 7ms/step - loss: 0.3979 - accuracy: 0.8319 - val_loss: 0.4650 - val_accuracy: 0.7792
# Epoch 10/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3827 - accuracy: 0.8353 - val_loss: 0.4579 - val_accuracy: 0.7698
# Epoch 11/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3733 - accuracy: 0.8438 - val_loss: 0.4581 - val_accuracy: 0.7698
# Epoch 12/400
# 23/23 [==============================] - 0s 6ms/step - loss: 0.3573 - accuracy: 0.8502 - val_loss: 0.4565 - val_accuracy: 0.7947
# Epoch 13/400
# 23/23 [==============================] - 0s 3ms/step - loss: 0.3469 - accuracy: 0.8555 - val_loss: 0.4619 - val_accuracy: 0.7854
# Epoch 14/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3345 - accuracy: 0.8642 - val_loss: 0.4618 - val_accuracy: 0.7916
# Epoch 15/400
# 23/23 [==============================] - 0s 4ms/step - loss: 0.3241 - accuracy: 0.8735 - val_loss: 0.4584 - val_accuracy: 0.7916
# Epoch 16/400
# 23/23 [==============================] - 0s 5ms/step - loss: 0.3053 - accuracy: 0.8813 - val_loss: 0.4674 - val_accuracy: 0.7854
# Epoch 17/400
#  1/23 [>.............................] - ETA: 0s - loss: 0.2844 - accuracy: 0.9023
# Epoch 00017: ReduceLROnPlateau reducing learning rate to 1.0000000474974512e-06.
# 23/23 [==============================] - 0s 4ms/step - loss: 0.2992 - accuracy: 0.8820 - val_loss: 0.4721 - val_accuracy: 0.7652
# Matthews Correlation :  0.41112986066894597
# Confusion Matrix :
#  [[248 120]
#  [ 97 271]]
# Accuracy on test set:    0.7051630434782609
# Sensitivity:    0.7364130434782609 	 Specificity:    0.6739130434782609
#               precision    recall  f1-score   support
#
#            0       0.72      0.67      0.70       368
#            1       0.69      0.74      0.71       368
#
#     accuracy                           0.71       736
#    macro avg       0.71      0.71      0.70       736
# weighted avg       0.71      0.71      0.70       736
#
# Area Under Curve:    0.7051630434782608
# Precision:    0.6930946291560103
#
# Seed   :     99
#
# dbPTM_ANN_program_first_revision99.h5

# %% [markdown]
# # Thank You.
